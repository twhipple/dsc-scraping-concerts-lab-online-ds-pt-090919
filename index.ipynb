# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %%
import re
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
# My code
events_page = requests.get('https://www.residentadvisor.net/events/us/massachusetts') # Make a get request to retrieve the page
soup = BeautifulSoup(events_page.content, 'html.parser')

# %%
# Their code
response = requests.get("https://www.residentadvisor.net/events/us/newyork")
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# My code
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Massachusetts, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, massachusetts, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=ATv7yC5anBBrxJoYdSr-DqUPyab_mqaaXHG0qxMzlYI1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/massachusetts").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "Massachusetts"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?637087023120864732"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2019/11">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./massachusetts?cc=us&amp;an=massachusetts" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="gKepKNZAX0xEg6gufOPt7xwcGEo9PvJPMRVa+B/Az8UsAKdwrDooWcjlUT3uOYYErdYEaoygPqF4oidSJ6vQqUnjf3I="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Massachusetts</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Thu, 7 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938"><img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/></a>
# <p class="counter nohide">
# <span>12</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938">
# <h1>
# Claude Vonstroke
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=146083">The Grand Boston</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 8 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002"><img class="nohide" src="/images/events/flyer/2019/11/us-1108-1331002-list.jpg"/></a>
# <p class="counter nohide">
# <span>44</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002">
# <h1>
# Visceral X Mess
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1336209-list.jpg"/></a>
# <p class="counter nohide">
# <span>18</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209">
# <h1>
# Sure Thing: Feral (Hypnus)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1338172-list.jpg"/></a>
# <p class="counter nohide">
# <span>10</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172">
# <h1>
# vyo͞o presents: Binh
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1334952-list.jpg"/></a>
# <p class="counter nohide">
# <span>38</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952">
# <h1>
# Only Friends 003
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1330029-list.jpg"/></a>
# <p class="counter nohide">
# <span>21</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029">
# <h1>
# Data Dreams: Akua, Aura T-09, Final Object, Dev / Chron
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 20 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256529"><img class="nohide" src="/images/events/flyer/2019/11/us-1120-1256529-list.jpg"/></a>
# <p class="counter nohide">
# <span>19</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1
ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=54268">Bijou Nightclub</a> /</li><li><a ga-event-action="The Middle East" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5216">The Middle East</a> /</li><li><a ga-event-action="Royale" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=32242">Royale</a> /</li><li><a ga-event-action="American Legion Marsh Post #442" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=10923">American Legion Marsh Post #442</a> /</li><li><a ga-event-action="The Lower Level" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=131409">The Lower Level</a> /</li><li><a ga-event-action="Paradise" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=9573">Paradise</a> /</li><li><a ga-event-action="Underbar" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=3618">Underbar</a> /</li><li><a ga-event-action="Machine" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=14939">Machine</a> /</li><li><a ga-event-action="House Of Blues" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=17756">House Of Blues</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=79">More Massachusetts clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Sydney" ga-event-category="top-regions" ga-on="click" href="/guide/au/sydney">Sydney, AU</a> /</li><li><a ga-event-action="Madrid" ga-event-category="top-regions" ga-on="click" href="/guide/es/madrid">Madrid, ES</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Brussels" ga-event-category="top-regions" ga-on="click" href="/guide/be/brussels">Brussels, BE</a> /</li><li><a ga-event-action="Leeds" ga-event-category="top-regions" ga-on="click" href="/guide/uk/leeds">Leeds, UK</a> /</li><li><a ga-event-action="Prague" ga-event-category="top-regions" ga-on="click" href="/guide/cz/prague">Prague, CZ</a> /</li><li><a ga-event-action="Zurich" ga-event-category="top-regions" ga-on="click" href="/guide/ch/zurich">Zurich, CH</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/massachusetts/week/2019-10-31">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/massachusetts/week/2019-11-14">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 31 Oct 2019</p>
# <a href="/news/44709">
# <img class="thumb" src="/images/news/2019/four-tet-unprounceable.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44709/?comments=1">Post a comment</a>
# </p><a href="/news/44709">
# <h1>Four Tet returns to ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ alias with two new tracks</h1>
# </a>
# <p class="copy">The titles are made up of unpronounceable symbols, as usual.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 01 Nov 2019</p>
# <a href="/news/44715">
# <img class="thumb" src="/images/news/2019/disclosure-sam-smith.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44715/?comments=1">Post a comment</a>
# </p><a href="/news/44715">
# <h1>Sam Smith and Disclosure's Guy Lawrence cover Donna Summer's 'I Feel Love'</h1>
# </a>
# <p class="copy">The cover of the Giorgio Moroder-produced classic will be featured in Target's Christmas-season ad campaign.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 04 Nov 2019</p>
# <a href="/news/44712">
# <img class="thumb" src="/images/news/2019/the-feed-rip.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44712/?comments=1">Post a comment</a>
# </p><a href="/news/44712">
# <h1>RA closes The Feed</h1>
# </a>
# <p class="copy">From now on, we'll be sharing our wide range of daily updates in the News section.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 01 Nov 2019</p>
# <a href="/news/44714">
# <img class="thumb" src="/images/news/2019/theo-parrish-sound-signature.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/
jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44707/?comments=1">Post a comment</a>
# </p><a href="/news/44707">
# <h1>Homoelectric's new Manchester festival Homobloc will partner with LGBT+ human rights group, All Out</h1>
# </a>
# <p class="copy">The queer party promoter will launch emergency advocacy campaigns for LGBT+ rights in Poland, Chechnya and beyond.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 04 Nov 2019</p>
# <a href="/news/70932">
# <img class="thumb" src="/images/news/2019/ocean-arca-remix.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70932/?comments=1">Post a comment</a>
# </p><a href="/news/70932">
# <h1>Arca remixes Frank Ocean</h1>
# </a>
# <p class="copy">The Venezuelan producer's version of "Little Demon" also features Skepta.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 01 Nov 2019</p>
# <a href="/news/44708">
# <img class="thumb" src="/images/news/2019/radioactive-man-20-year-retrospective-box-set-doors-to-manual-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44708/?comments=1">Post a comment</a>
# </p><a href="/news/44708">
# <h1>Radioactive Man reveals 20-year career retrospective, Doors To Manual</h1>
# </a>
# <p class="copy">The four-piece, vinyl-only box set arrives on November 29th via his own label Asking for Trouble.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 01 Nov 2019</p>
# <a href="/news/44705">
# <img class="thumb" src="/images/news/2019/dj-nobu-rainbow-disco-club-festival-beyond-space-time-compilatilon-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44705/?comments=1">Post a comment</a>
# </p><a href="/news/44705">
# <h1>Rainbow Disco Club launches new label with DJ Nobu-curated compilation</h1>
# </a>
# <p class="copy">Out November 25th, the first release on Beyond Space And Time asks, "what is in a DJ's record bag?"</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 06 Nov 2019</p>
# <a href="/news/70970">
# <img class="thumb" src="/images/news/2019/ableton-granular-synth-grain-scanner.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70970/?comments=1">Post a comment</a>
# </p><a href="/news/70970">
# <h1>Ableton gets new granular synth, Grain Scanner</h1>
# </a>
# <p class="copy">The €49 sound design tool was developed by Amazing Noises.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 05 Nov 2019</p>
# <a href="/news/70957">
# <img class="thumb" src="/images/news/2019/bicep-live-o2-brixton-academy-london-march-2020.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70957/?comments=1">Post a comment</a>
# </p><a href="/news/70957">
# <h1>Bicep announce new live date in London</h1>
# </a>
# <p class="copy">The UK duo will headline O2 Academy Brixton on March 27th, 2020.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 04 Nov 2019</p>
# <a href="/news/70942">
# <img class="thumb" src="/images/news/2019/studioolo-compilation-antinote.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70942/?comments=1">Post a comment</a>
# </p><a href="/news/70942">
# <h1>Antinote and Dizonord reveal compilation of slo-mo Afro and cosmic music from the '90s</h1>
# </a>
# <p class="copy">Studiolo highlights trance and prog house tracks that were often played at the wrong speed by Italian, German and Austrian DJs.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 04 Nov 2019</p>
# <a href="/news/70937">
# <img class="thumb" src="/images/news/2019/space289.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/70937/?comments=1">Post a comment</a>
# </p><a href="/news/70937">
# <h1>New venue Space289 to open in East London</h1>
# </a>
# <p class="copy">The live music space will officially launch in spring 2020.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 02 Nov 2019</p>
# <a href="/news/52082">
# <img class="thumb" src="/images/news/2019/andrew-weatherall-motd.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/52082/?comments=1">Post a comment</a>
# </p><a href="/news/52082">
# <h1>Mix of the day: Andrew Weatherall</h1>
# </a>
# <p class="copy">Here's the first hour of Weatherall's opening set at 909 in Liverpool last month.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2019 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
event_list = soup.find('div', class_="strip slide small")
event_list
# Out:
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Thu, 7 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938"><img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/></a>
# <p class="counter nohide">
# <span>12</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938">
# <h1>
# Claude Vonstroke
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=146083">The Grand Boston</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 8 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002"><img class="nohide" src="/images/events/flyer/2019/11/us-1108-1331002-list.jpg"/></a>
# <p class="counter nohide">
# <span>44</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002">
# <h1>
# Visceral X Mess
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1336209-list.jpg"/></a>
# <p class="counter nohide">
# <span>18</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209">
# <h1>
# Sure Thing: Feral (Hypnus)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1338172-list.jpg"/></a>
# <p class="counter nohide">
# <span>10</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172">
# <h1>
# vyo͞o presents: Binh
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1334952-list.jpg"/></a>
# <p class="counter nohide">
# <span>38</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952">
# <h1>
# Only Friends 003
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1330029-list.jpg"/></a>
# <p class="counter nohide">
# <span>21</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029">
# <h1>
# Data Dreams: Akua, Aura T-09, Final Object, Dev / Chron
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 20 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256529"><img class="nohide" src="/images/events/flyer/2019/11/us-1120-1256529-list.jpg"/></a>
# <p class="counter nohide">
# <span>19</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256529">
# <h1>
# Gesaffelstein
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=17756">House Of Blues</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 4 Dec 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1305930"><img class="nohide" src="/images/events/flyer/dj/desertsoundcolony-list.jpg"/></a>
# <p class="counter nohide">
# <span>9</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1305930">
# <h1>
# Re:Set with Desert Sound Colony
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=10356">Phoenix Landing</a>
# </p>
# </article>
# </li> </ul>
# </div>

# %%
next_container = event_list.nextSibling.nextSibling 
next_container
# Out:
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>

# %%
titles = event_list.findAll('li') # Make a selection
titles[1]
# Out:
# <li class="">
# <article class="highlight-top">
# <p>Fri, 8 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002"><img class="nohide" src="/images/events/flyer/2019/11/us-1108-1331002-list.jpg"/></a>
# <p class="counter nohide">
# <span>44</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002">
# <h1>
# Visceral X Mess
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li>

# %%
titles[0].find('h1')
# Out:
# <h1>
# Claude Vonstroke
# </h1>

# %%
titles[0].find('img')
# Out:
# <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>

# %%
final_titles = [event_list.find('h1') for h1 in event_list.findAll('h1')]
print(len(final_titles), final_titles[:])
# Out:
# 8 [<h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>]

# %%
new_event_list = soup.find('ul', class_="list small clearfix popular")
new_event_list
# Out:
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Thu, 7 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938"><img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/></a>
# <p class="counter nohide">
# <span>12</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1304938">
# <h1>
# Claude Vonstroke
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=146083">The Grand Boston</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 8 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002"><img class="nohide" src="/images/events/flyer/2019/11/us-1108-1331002-list.jpg"/></a>
# <p class="counter nohide">
# <span>44</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1331002">
# <h1>
# Visceral X Mess
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1336209-list.jpg"/></a>
# <p class="counter nohide">
# <span>18</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1336209">
# <h1>
# Sure Thing: Feral (Hypnus)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 9 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172"><img class="nohide" src="/images/events/flyer/2019/11/us-1109-1338172-list.jpg"/></a>
# <p class="counter nohide">
# <span>10</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1338172">
# <h1>
# vyo͞o presents: Binh
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1334952-list.jpg"/></a>
# <p class="counter nohide">
# <span>38</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1334952">
# <h1>
# Only Friends 003
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Boston
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 16 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029"><img class="nohide" src="/images/events/flyer/2019/11/us-1116-1330029-list.jpg"/></a>
# <p class="counter nohide">
# <span>21</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1330029">
# <h1>
# Data Dreams: Akua, Aura T-09, Final Object, Dev / Chron
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=131409">The Lower Level</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 20 Nov 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256529"><img class="nohide" src="/images/events/flyer/2019/11/us-1120-1256529-list.jpg"/></a>
# <p class="counter nohide">
# <span>19</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256529">
# <h1>
# Gesaffelstein
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=17756">House Of Blues</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 4 Dec 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1305930"><img class="nohide" src="/images/events/flyer/dj/desertsoundcolony-list.jpg"/></a>
# <p class="counter nohide">
# <span>9</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1305930">
# <h1>
# Re:Set with Desert Sound Colony
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=10356">Phoenix Landing</a>
# </p>
# </article>
# </li> </ul>

# %%
new_titles = new_event_list.findAll('h1') # Make a selection
new_titles[2]
# Out:
# <h1>
# Sure Thing: Feral (Hypnus)
# </h1>

# %%
new_final_titles = [new_titles.find('h1') for h1 in new_titles.findAll('h1')]
print(len(new_final_titles), new_final_titles[:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-f2c52937c542> in <module>()
# ----> 1 new_final_titles = [new_titles.find('h1') for h1 in new_titles.findAll('h1')]
#       2 print(len(new_final_titles), new_final_titles[:])
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
all_final_titles = [new_event_list.find('h1') for h1 in new_event_list.findAll('h1')]
print(len(final_titles), final_titles[:5])
# Out:
# 8 [<h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>, <h1>
# Claude Vonstroke
# </h1>]

# %%
images = new_event_list.findAll('img')
ex_img = images[2] # Preview an entry
ex_img
# Out:
# <img class="nohide" src="/images/events/flyer/2019/11/us-1109-1336209-list.jpg"/>

# %%
final_images = [new_event_list.find('img') for img in new_event_list.findAll('img')]
print(len(final_images), final_images[:])
# Out:
# 8 [<img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>, <img class="nohide" src="/images/events/flyer/2019/11/us-1107-1304938-list.jpg"/>]

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    #Your code here
    warning = soup.find('div', class_="alert alert-warning")
    book_container = warning.nextSibling.nextSibling
    titles = [h3.find('a').attrs['title'] for h3 in book_container.findAll('h3')]
    return titles
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!

# %%
event_listings = soup.find('div', id="event-listing")

# %%
entries = event_listings.findAll('li')
print(len(entries), entries[0])
# Out:
# 13 <li><p class="eventDate date"><a href="/events.aspx?ai=79&amp;v=day&amp;mn=11&amp;yr=2019&amp;dy=7"><span>Thu, 07 Nov 2019 /</span></a></p></li>

# %%
#Successive exploration in function development
rows = []
for entry in entries:
    #Is it a date? If so, set current date.
    date = entry.find('p', class_="eventDate date")
    event = entry.find('h1', class_="event-title")
    if event:
        details = event.text.split(' at ')
        event_name = details[0].strip()
        venue = details[1].strip()
        try:
            n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
        except:
            n_attendees = np.nan
        rows.append([event_name, venue, cur_date, n_attendees])
    elif date:
        cur_date = date.text
    else:
        continue
df = pd.DataFrame(rows)
df.head()
# Out:
#                                                 0                 1  \
# 0                                Claude Vonstroke  The Grand Boston
# 1  Takeover with Matt Mcneill, Mrph, Ryan Perkins              Zuzu
# 2                                 Visceral X Mess   The Lower Level
# 3                      Sure Thing: Feral (Hypnus)   The Lower Level
# 4                            vyo͞o presents: Binh      TBA - Boston
#
#                     2   3
# 0  Thu, 07 Nov 2019 /  12
# 1  Thu, 07 Nov 2019 /   3
# 2  Fri, 08 Nov 2019 /  44
# 3  Sat, 09 Nov 2019 /  18
# 4  Sat, 09 Nov 2019 /  10

# %%
#Final function
def scrape_events(events_page_url):
    #Your code here
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    entries = event_listings.findAll('li')
    rows = []
    for entry in entries:
        #Is it a date? If so, set current date.
        date = entry.find('p', class_="eventDate date")
        event = entry.find('h1', class_="event-title")
        if event:
            details = event.text.split(' at ')
            event_name = details[0].strip()
            venue = details[1].strip()
            try:
                n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
            except:
                n_attendees = np.nan
            rows.append([event_name, venue, cur_date, n_attendees])
        elif date:
            cur_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.head()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
# Function development cell
soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
# Out:
# '/events/us/massachusetts/week/2019-11-14'

# %%
# Write a Function to Retrieve the URL for the Next Page
def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + url_ext
    #Your code here
    return next_page_url

# %%
# Scrape the Next 1000 Events for Your Area
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events/us/newyork"
while total_rows <= 1000:
    df = scrape_events(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
    time.sleep(.2)
df = pd.concat(dfs)
df = df.iloc[:1000]
print(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-0f91a9bf1abb> in <module>()
#       7     dfs.append(df)
#       8     total_rows += len(df)
# ----> 9     cur_url = next_page(cur_url)
#      10     time.sleep(.2)
#      11 df = pd.concat(dfs)
#
# <ipython-input-57-43a29f3f2c13> in next_page(url)
#       2     response = requests.get(url)
#       3     soup = BeautifulSoup(response.content, 'html.parser')
# ----> 4     url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
#       5     next_page_url = "https://www.residentadvisor.net" + url_ext
#       6     #Your code here
#
# AttributeError: 'NoneType' object has no attribute 'attrs'
